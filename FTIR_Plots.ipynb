# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

def get_FTIR_data(file_paths, wn_bounds):

    FTIR_data = []

    for file in file_paths:

        data = np.loadtxt(file, delimiter='\t')

        wave_number = data[:,0]
        reflectance = data[:,1]

        mask = (wave_number >= wn_bounds[0]) & (wave_number <= wn_bounds[1])

        wave_number_filtered = wave_number[mask]
        reflectance_filtered = reflectance[mask]

        filtered_data = (wave_number_filtered, reflectance_filtered)
        FTIR_data.append(filtered_data)
    
    return FTIR_data


def plot_FTIR(FTIR_data, title, xlabel, ylabel, legend_keys):

    colors = colors = ['k', 'r', 'b', 'g', 'm']
    
    plt.figure(figsize=(15,10))
    for index, data in enumerate(FTIR_data):
        x = data[0]
        y = data[1]
        plt.plot(x, y, color=colors[index], linewidth=2, label=legend_keys[index])

    plt.grid(True, alpha=0.5)
    plt.xlabel(xlabel, fontsize=30)
    plt.ylabel(ylabel, fontsize=30)
    plt.title(title, fontsize=30)
    plt.tick_params(axis='both', which='major', labelsize=30)
    plt.legend(fontsize=30)
    plt.show()

# %% [markdown]
# ### FTIR Plots NRS06032024

# %%
wn_bounds = [700, 1000]
xlabel = "Wavenumber (cm^-1)"
ylabel = "Reflectance (%)"

title_1 = "TLW-1 BLW-5 S-1 H-xx"
legend_keys_1 = ["H-1", "H-2", "H-3", "H-4", "H-5"]
paths_1 = [
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-1_H-xx_dpt/25-11-02_21-58_NRS06032024_TLW-1_BLW-5_S-1_H-1.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-1_H-xx_dpt/25-11-02_22-14_NRS06032024_TLW-1_BLW-5_S-1_H-2.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-1_H-xx_dpt/25-11-02_22-31_NRS06032024_TLW-1_BLW-5_S-1_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-1_H-xx_dpt/25-11-02_22-59_NRS06032024_TLW-1_BLW-5_S-1_H-4.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-1_H-xx_dpt/25-11-02_23-21_NRS06032024_TLW-1_BLW-5_S-1_H-5.dpt"
]

title_2 = "TLW-1 BLW-5 S-xx H-3"
legend_keys_2 = ["S-1", "S-2", "S-3", "S-4", "S-5"]
paths_2 = [
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-5_S-1_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-5_S-2_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-5_S-3_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-5_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-5_S-5_H-3.dpt"
]

title_3 = "TLW-1 BLW-xx S-4 H-3"
legend_keys_3 = ["BLW-1", "BLW-2", "BLW-3", "BLW-4", "BLW-5"]
paths_3 = [
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-xx_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-1_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-xx_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-2_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-xx_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-3_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-xx_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-1_BLW-xx_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-5_S-4_H-3.dpt"
]

title_4 = "TLW-5 BLW-5 S-xx H-3"
legend_keys_4 = ["S-1", "S-2", "S-3", "S-4", "S-5"]
paths_4 = [
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-5_BLW-5_S-1_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-5_BLW-5_S-2_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-5_BLW-5_S-3_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-5_BLW-5_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-5_S-xx_H-3_dpt/2025-06-11_NRS06032024_TLW-5_BLW-5_S-5_H-3.dpt"
]

title_5 = "TLW-5 BLW-xx S-4 H-3"
legend_keys_5 = ["BLW-1", "BLW-2", "BLW-3", "BLW-4", "BLW-5"]
paths_5 = [
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-xx_S-4_H-3_dpt/25-11-02_20-04_NRS06032024_TLW-5_BLW-1_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-xx_S-4_H-3_dpt/25-11-02_20-24_NRS06032024_TLW-5_BLW-2_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-xx_S-4_H-3_dpt/25-11-02_20-45_NRS06032024_TLW-5_BLW-3_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-xx_S-4_H-3_dpt/25-11-02_21-07_NRS06032024_TLW-5_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-5_BLW-xx_S-4_H-3_dpt/25-11-02_21-25_NRS06032024_TLW-5_BLW-5_S-4_H-3.dpt"
]

title_6 = "TLW-xx BLW-4 S-4 H-3"
legend_keys_6 = ["TLW-1", "TLW-2", "TLW-3", "TLW-4", "TLW-5"]
paths_6 = [
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-xx_BLW-4_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-1_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-xx_BLW-4_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-2_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-xx_BLW-4_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-3_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-xx_BLW-4_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-4_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024_FTIR_dpt_15x_90deg_second_measurements/NRS06032024_TLW-xx_BLW-4_S-4_H-3_dpt/2025-06-11_NRS06032024_TLW-5_BLW-4_S-4_H-3.dpt"
]


FTIR_data_1 = get_FTIR_data(paths_1, wn_bounds)
plot_FTIR(FTIR_data_1, title_1, xlabel, ylabel, legend_keys_1)

FTIR_data_2 = get_FTIR_data(paths_2, wn_bounds)
plot_FTIR(FTIR_data_2, title_2, xlabel, ylabel, legend_keys_2)

FTIR_data_3 = get_FTIR_data(paths_3, wn_bounds)
plot_FTIR(FTIR_data_3, title_3, xlabel, ylabel, legend_keys_3)

FTIR_data_4 = get_FTIR_data(paths_4, wn_bounds)
plot_FTIR(FTIR_data_4, title_4, xlabel, ylabel, legend_keys_4)

FTIR_data_5 = get_FTIR_data(paths_5, wn_bounds)
plot_FTIR(FTIR_data_5, title_5, xlabel, ylabel, legend_keys_5)

FTIR_data_6 = get_FTIR_data(paths_6, wn_bounds)
plot_FTIR(FTIR_data_6, title_6, xlabel, ylabel, legend_keys_6)
print(FTIR_data_6)
# Out:
# [(array([700.02781, 700.50993, 700.99204, 701.47415, 701.95626, 702.43838,
#        702.92049, 703.4026 , 703.88472, 704.36683, 704.84894, 705.33105,
#        705.81317, 706.29528, 706.77739, 707.2595 , 707.74162, 708.22373,
#        708.70584, 709.18796, 709.67007, 710.15218, 710.63429, 711.11641,
#        711.59852, 712.08063, 712.56275, 713.04486, 713.52697, 714.00908,
#        714.4912 , 714.97331, 715.45542, 715.93754, 716.41965, 716.90176,
#        717.38387, 717.86599, 718.3481 , 718.83021, 719.31233, 719.79444,
#        720.27655, 720.75866, 721.24078, 721.72289, 722.205  , 722.68711,
#        723.16923, 723.65134, 724.13345, 724.61557, 725.09768, 725.57979,
#        726.0619 , 726.54402, 727.02613, 727.50824, 727.99036, 728.47247,
#        728.95458, 729.43669, 729.91881, 730.40092, 730.88303, 731.36515,
#        731.84726, 732.32937, 732.81148, 733.2936 , 733.77571, 734.25782,
#        734.73994, 735.22205, 735.70416, 736.18627, 736.66839, 737.1505 ,
# ...

# %% [markdown]
# ### FTIR Plots NRS06032024-2

# %%
wn_bounds = [700, 1000]
xlabel = "Wavenumber (cm^-1)"
ylabel = "Reflectance (%)"

title_1 = "TLW-1 BLW-5 S-1 H-xx"
legend_keys_1 = ["H-1", "H-2", "H-3", "H-4", "H-5"]
paths_1 = [
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-1_H-xx_dpt/25-10-10_NRS06032024-2_TLW-1_BLW-5_S-1_H-1.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-1_H-xx_dpt/25-10-10_NRS06032024-2_TLW-1_BLW-5_S-1_H-2.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-1_H-xx_dpt/25-10-10_NRS06032024-2_TLW-1_BLW-5_S-1_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-1_H-xx_dpt/25-10-10_NRS06032024-2_TLW-1_BLW-5_S-1_H-4.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-1_H-xx_dpt/25-10-10_NRS06032024-2_TLW-1_BLW-5_S-1_H-5.dpt"]

title_2 = "TLW-1 BLW-5 S-xx H-3"
legend_keys_2 = ["S-1", "S-2", "S-3", "S-4", "S-5"]
paths_2 = [
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-xx_H-3_dpt/25-09-10_NRS06032024-2_TLW-1_BLW-5_S-1_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-xx_H-3_dpt/25-09-10_NRS06032024-2_TLW-1_BLW-5_S-2_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-xx_H-3_dpt/25-09-10_NRS06032024-2_TLW-1_BLW-5_S-3_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-xx_H-3_dpt/25-09-10_NRS06032024-2_TLW-1_BLW-5_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-5_S-xx_H-3_dpt/25-09-10_NRS06032024-2_TLW-1_BLW-5_S-5_H-3.dpt"]

title_3 = "TLW-1 BLW-xx S-4 H-3"
legend_keys_3 = ["BLW-1", "BLW-2", "BLW-3", "BLW-4", "BLW-5"]
paths_3 = [
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-xx_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-1_BLW-1_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-xx_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-1_BLW-2_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-xx_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-1_BLW-3_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-xx_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-1_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-1_BLW-xx_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-1_BLW-5_S-4_H-3.dpt"]

title_4 = "TLW-5 BLW-xx S-4 H-3"
legend_keys_4 = ["BLW-1", "BLW-2", "BLW-3", "BLW-4", "BLW-5"]
paths_4 = [
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-5_BLW-xx_S-4_H-3_dpt/25-09-10_NRS06032024-2_TLW-5_BLW-1_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-5_BLW-xx_S-4_H-3_dpt/25-09-10_NRS06032024-2_TLW-5_BLW-2_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-5_BLW-xx_S-4_H-3_dpt/25-09-10_NRS06032024-2_TLW-5_BLW-3_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-5_BLW-xx_S-4_H-3_dpt/25-09-10_NRS06032024-2_TLW-5_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-5_BLW-xx_S-4_H-3_dpt/25-09-10_NRS06032024-2_TLW-5_BLW-5_S-4_H-3.dpt"]

title_5 = "TLW-xx BLW-4 S-4 H-3"
legend_keys_5 = ["TLW-1", "TLW-2", "TLW-3", "TLW-4", "TLW-5"]
paths_5 = [
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-xx_BLW-4_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-1_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-xx_BLW-4_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-2_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-xx_BLW-4_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-3_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-xx_BLW-4_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-4_BLW-4_S-4_H-3.dpt",
    "./Data/FTIR/NRS06032024-2_FTIR_dpt_36x_90deg_first_measurements/NRS06032024-2_TLW-xx_BLW-4_S-4_H-3_dpt/25-07-09_NRS06032024-2_TLW-5_BLW-4_S-4_H-3.dpt"]


FTIR_data_1 = get_FTIR_data(paths_1, wn_bounds)
plot_FTIR(FTIR_data_1, title_1, xlabel, ylabel, legend_keys_1)

FTIR_data_2 = get_FTIR_data(paths_2, wn_bounds)
plot_FTIR(FTIR_data_2, title_2, xlabel, ylabel, legend_keys_2)

FTIR_data_3 = get_FTIR_data(paths_3, wn_bounds)
plot_FTIR(FTIR_data_3, title_3, xlabel, ylabel, legend_keys_3)

FTIR_data_4 = get_FTIR_data(paths_4, wn_bounds)
plot_FTIR(FTIR_data_4, title_4, xlabel, ylabel, legend_keys_4)

FTIR_data_5 = get_FTIR_data(paths_5, wn_bounds)
plot_FTIR(FTIR_data_5, title_5, xlabel, ylabel, legend_keys_5)

# %%
# extracting absorption curves
wn_min = 900
wn_max = 960
window = 100
poly_order = 3
absorption_curves_1 = []
wn_1 = []

for data in FTIR_data_1:
    wn = data[0] 
    R = data[1]

    # Take limits and Normalize
    mask = (wn >= wn_min) & (wn <= wn_max)
    wn_w = wn[mask]
    R_w = R[mask] / np.max(R[mask])
    plt.plot(wn_w, 1 - R_w)
    plt.grid(alpha=0.5)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
